# %%
# !git clone https://github.com/BeastOrchestra/tft_v0.git
# %cd tft_v0
# !pip install pytorch-forecasting pytorch-lightning
# !pip install boto3
import boto3
# Out:
# Cloning into 'tft_v0'...
# remote: Enumerating objects: 384, done.
# remote: Total 384 (delta 0), reused 0 (delta 0), pack-reused 384 (from 2)
# Receiving objects: 100% (384/384), 411.18 MiB | 68.23 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# Updating files: 100% (296/296), done.
# /home/ubuntu/tft_v0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytorch-forecasting
#   Downloading pytorch_forecasting-1.3.0-py3-none-any.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 KB 3.3 MB/s eta 0:00:00a 0:00:01
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl (819 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 KB 6.6 MB/s eta 0:00:00a 0:00:01
# Collecting lightning<3.0.0,>=2.0.0
#   Downloading lightning-2.5.0.post0-py3-none-any.whl (815 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 KB 9.2 MB/s eta 0:00:00a 0:00:01
# Collecting scikit-learn<2.0,>=1.2
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (12.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 31.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<=3.0.0 in /usr/lib/python3/dist-packages (from pytorch-forecasting) (1.21.5)
# Requirement already satisfied: torch!=2.0.1,<3.0.0,>=2.0.0 in /usr/lib/python3/dist-packages (from pytorch-forecasting) (2.5.1)
# Requirement already satisfied: pandas<3.0.0,>=1.3.0 in /usr/lib/python3/dist-packages (from pytorch-forecasting) (1.3.5)
# Requirement already satisfied: scipy<2.0,>=1.8 in /usr/lib/python3/dist-packages (from pytorch-forecasting) (1.8.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/lib/python3/dist-packages (from pytorch-lightning) (5.4.1)
# Collecting lightning-utilities>=0.10.0
#   Downloading lightning_utilities-0.12.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/lib/python3/dist-packages (from pytorch-lightning) (4.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from pytorch-lightning) (21.3)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 KB 49.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/lib/python3/dist-packages (from pytorch-lightning) (2024.3.1)
# Collecting tqdm>=4.57.0
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 29.9 MB/s eta 0:00:00
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.11.13-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 57.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (59.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/lib/python3/dist-packages (from scikit-learn<2.0,>=1.2->pytorch-forecasting) (3.1.0)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 KB 72.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (21.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 KB 59.1 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.6/126.6 KB 48.2 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.18.3-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (315 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.3/315.3 KB 61.2 MB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.0-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (205 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 KB 55.9 MB/s eta 0:00:00
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.3)
# Installing collected packages: tqdm, propcache, multidict, lightning-utilities, joblib, frozenlist, async-timeout, aiohappyeyeballs, yarl, torchmetrics, scikit-learn, aiosignal, aiohttp, pytorch-lightning, lightning, pytorch-forecasting
# Successfully installed aiohappyeyeballs-2.4.6 aiohttp-3.11.13 aiosignal-1.3.2 async-timeout-5.0.1 frozenlist-1.5.0 joblib-1.4.2 lightning-2.5.0.post0 lightning-utilities-0.12.0 multidict-6.1.0 propcache-0.3.0 pytorch-forecasting-1.3.0 pytorch-lightning-2.5.0.post0 scikit-learn-1.6.1 torchmetrics-1.6.1 tqdm-4.67.1 yarl-1.18.3

# %%
# Now, you are in tft_v0
# Navigate to data and delete train/test/oos folders
# open a terminal and promopt: aws configure
# enter credentials

# %%
import boto3
import os
from pathlib import Path

def download_from_s3(bucket_name, s3_folder, local_dir):
    s3_client = boto3.client('s3')
    paginator = s3_client.get_paginator('list_objects_v2')
    
    # Ensure the local directory exists
    local_dir = Path(local_dir)
    local_dir.mkdir(parents=True, exist_ok=True)

    for page in paginator.paginate(Bucket=bucket_name, Prefix=s3_folder):
        if 'Contents' in page:
            for obj in page['Contents']:
                s3_key = obj['Key']
                rel_path = s3_key[len(s3_folder):].lstrip("/")  # Remove folder prefix
                local_path = local_dir / rel_path
                
                # Ensure parent directories exist
                local_path.parent.mkdir(parents=True, exist_ok=True)
                
                print(f"Downloading {s3_key} to {local_path}...")
                s3_client.download_file(bucket_name, s3_key, str(local_path))

# Example Usage
download_from_s3('arj-ibdata', 'data/', './data')
# Out:
# Downloading data/.DS_Store to data/.DS_Store...
# Downloading data/TixMuSig.csv to data/TixMuSig.csv...
# Downloading data/oos/.DS_Store to data/oos/.DS_Store...
# Downloading data/oos/AAPL.csv to data/oos/AAPL.csv...
# Downloading data/oos/ABBV.csv to data/oos/ABBV.csv...
# Downloading data/oos/ABT.csv to data/oos/ABT.csv...
# Downloading data/oos/ACN.csv to data/oos/ACN.csv...
# Downloading data/oos/ADBE.csv to data/oos/ADBE.csv...
# Downloading data/oos/ADI.csv to data/oos/ADI.csv...
# Downloading data/oos/ADP.csv to data/oos/ADP.csv...
# Downloading data/oos/ADSK.csv to data/oos/ADSK.csv...
# Downloading data/oos/AEP.csv to data/oos/AEP.csv...
# Downloading data/oos/AFL.csv to data/oos/AFL.csv...
# Downloading data/oos/AIG.csv to data/oos/AIG.csv...
# Downloading data/oos/AJG.csv to data/oos/AJG.csv...
# Downloading data/oos/ALL.csv to data/oos/ALL.csv...
# Downloading data/oos/AMAT.csv to data/oos/AMAT.csv...
# Downloading data/oos/AMGN.csv to data/oos/AMGN.csv...
# Downloading data/oos/AMP.csv to data/oos/AMP.csv...
# Downloading data/oos/AMT.csv to data/oos/AMT.csv...
# Downloading data/oos/AMZN.csv to data/oos/AMZN.csv...
# Downloading data/oos/AON.csv to data/oos/AON.csv...
# Downloading data/oos/APD.csv to data/oos/APD.csv...
# Downloading data/oos/APH.csv to data/oos/APH.csv...
# Downloading data/oos/AXP.csv to data/oos/AXP.csv...
# Downloading data/oos/AZO.csv to data/oos/AZO.csv...
# Downloading data/oos/BA.csv to data/oos/BA.csv...
# Downloading data/oos/BAC.csv to data/oos/BAC.csv...
# Downloading data/oos/BDX.csv to data/oos/BDX.csv...
# Downloading data/oos/BK.csv to data/oos/BK.csv...
# Downloading data/oos/BKNG.csv to data/oos/BKNG.csv...
# Downloading data/oos/BLK.csv to data/oos/BLK.csv...
# Downloading data/oos/BMY.csv to data/oos/BMY.csv...
# Downloading data/oos/BRK B.csv to data/oos/BRK B.csv...
# Downloading data/oos/BSX.csv to data/oos/BSX.csv...
# Downloading data/oos/BX.csv to data/oos/BX.csv...
# Downloading data/oos/C.csv to data/oos/C.csv...
# Downloading data/oos/CAT.csv to data/oos/CAT.csv...
# Downloading data/oos/CB.csv to data/oos/CB.csv...
# Downloading data/oos/CDNS.csv to data/oos/CDNS.csv...
# Downloading data/oos/CI.csv to data/oos/CI.csv...
# Downloading data/oos/CL.csv to data/oos/CL.csv...
# Downloading data/oos/CMCSA.csv to data/oos/CMCSA.csv...
# Downloading data/oos/CME.csv to data/oos/CME.csv...
# Downloading data/oos/CMG.csv to data/oos/CMG.csv...
# Downloading data/oos/CMI.csv to data/oos/CMI.csv...
# Downloading data/oos/COF.csv to data/oos/COF.csv...
# Downloading data/oos/COP.csv to data/oos/COP.csv...
# Downloading data/oos/COST.csv to data/oos/COST.csv...
# Downloading data/oos/CPRT.csv to data/oos/CPRT.csv...
# Downloading data/oos/CRM.csv to data/oos/CRM.csv...
# Downloading data/oos/CSCO.csv to data/oos/CSCO.csv...
# Downloading data/oos/CTAS.csv to data/oos/CTAS.csv...
# Downloading data/oos/CVS.csv to data/oos/CVS.csv...
# Downloading data/oos/CVX.csv to data/oos/CVX.csv...
# Downloading data/oos/D.csv to data/oos/D.csv...
# Downloading data/oos/DE.csv to data/oos/DE.csv...
# Downloading data/oos/DFS.csv to data/oos/DFS.csv...
# Downloading data/oos/DHR.csv to data/oos/DHR.csv...
# Downloading data/oos/DIS.csv to data/oos/DIS.csv...
# Downloading data/oos/DLR.csv to data/oos/DLR.csv...
# Downloading data/oos/DUK.csv to data/oos/DUK.csv...
# Downloading data/oos/ECL.csv to data/oos/ECL.csv...
# Downloading data/oos/ELV.csv to data/oos/ELV.csv...
# Downloading data/oos/EMR.csv to data/oos/EMR.csv...
# Downloading data/oos/EOG.csv to data/oos/EOG.csv...
# Downloading data/oos/EQIX.csv to data/oos/EQIX.csv...
# Downloading data/oos/ETN.csv to data/oos/ETN.csv...
# Downloading data/oos/FCX.csv to data/oos/FCX.csv...
# Downloading data/oos/FDX.csv to data/oos/FDX.csv...
# Downloading data/oos/FI.csv to data/oos/FI.csv...
# Downloading data/oos/FTNT.csv to data/oos/FTNT.csv...
# Downloading data/oos/GD.csv to data/oos/GD.csv...
# Downloading data/oos/GE.csv to data/oos/GE.csv...
# Downloading data/oos/GILD.csv to data/oos/GILD.csv...
# Downloading data/oos/GM.csv to data/oos/GM.csv...
# Downloading data/oos/GOOGL.csv to data/oos/GOOGL.csv...
# Downloading data/oos/GS.csv to data/oos/GS.csv...
# Downloading data/oos/HCA.csv to data/oos/HCA.csv...
# Downloading data/oos/HD.csv to data/oos/HD.csv...
# Downloading data/oos/HON.csv to data/oos/HON.csv...
# Downloading data/oos/HWM.csv to data/oos/HWM.csv...
# Downloading data/oos/IBM.csv to data/oos/IBM.csv...
# Downloading data/oos/ICE.csv to data/oos/ICE.csv...
# Downloading data/oos/INTC.csv to data/oos/INTC.csv...
# Downloading data/oos/INTU.csv to data/oos/INTU.csv...
# Downloading data/oos/ISRG.csv to data/oos/ISRG.csv...
# Downloading data/oos/ITW.csv to data/oos/ITW.csv...
# Downloading data/oos/JCI.csv to data/oos/JCI.csv...
# Downloading data/oos/JNJ.csv to data/oos/JNJ.csv...
# Downloading data/oos/JPM.csv to data/oos/JPM.csv...
# Downloading data/oos/KKR.csv to data/oos/KKR.csv...
# Downloading data/oos/KLAC.csv to data/oos/KLAC.csv...
# Downloading data/oos/KMB.csv to data/oos/KMB.csv...
# Downloading data/oos/KMI.csv to data/oos/KMI.csv...
# Downloading data/oos/KO.csv to data/oos/KO.csv...
# Downloading data/oos/SBUX.csv to data/oos/SBUX.csv...
# Downloading data/oos/SCHW.csv to data/oos/SCHW.csv...
# Downloading data/oos/SHW.csv to data/oos/SHW.csv...
# Downloading data/oos/SLB.csv to data/oos/SLB.csv...
# Downloading data/oos/SNPS.csv to data/oos/SNPS.csv...
# Downloading data/oos/SO.csv to data/oos/SO.csv...
# Downloading data/oos/SPG.csv to data/oos/SPG.csv...
# Downloading data/oos/SPGI.csv to data/oos/SPGI.csv...
# Downloading data/oos/SRE.csv to data/oos/SRE.csv...
# Downloading data/oos/SYK.csv to data/oos/SYK.csv...
# Downloading data/oos/T.csv to data/oos/T.csv...
# Downloading data/oos/TDG.csv to data/oos/TDG.csv...
# Downloading data/oos/TFC.csv to data/oos/TFC.csv...
# Downloading data/oos/TGT.csv to data/oos/TGT.csv...
# Downloading data/oos/TJX.csv to data/oos/TJX.csv...
# Downloading data/oos/TMO.csv to data/oos/TMO.csv...
# Downloading data/oos/TRV.csv to data/oos/TRV.csv...
# Downloading data/oos/TSLA.csv to data/oos/TSLA.csv...
# Downloading data/oos/TT.csv to data/oos/TT.csv...
# Downloading data/oos/TXN.csv to data/oos/TXN.csv...
# Downloading data/oos/UNH.csv to data/oos/UNH.csv...
# Downloading data/oos/UNP.csv to data/oos/UNP.csv...
# Downloading data/oos/UPS.csv to data/oos/UPS.csv...
# Downloading data/oos/USB.csv to data/oos/USB.csv...
# Downloading data/oos/V.csv to data/oos/V.csv...
# Downloading data/oos/VRTX.csv to data/oos/VRTX.csv...
# Downloading data/oos/VZ.csv to data/oos/VZ.csv...
# Downloading data/oos/WELL.csv to data/oos/WELL.csv...
# Downloading data/oos/WFC.csv to data/oos/WFC.csv...
# Downloading data/oos/WM.csv to data/oos/WM.csv...
# Downloading data/oos/WMB.csv to data/oos/WMB.csv...
# Downloading data/oos/WMT.csv to data/oos/WMT.csv...
# Downloading data/oos/XOM.csv to data/oos/XOM.csv...
# Downloading data/oos/ZTS.csv to data/oos/ZTS.csv...
# Downloading data/test/.DS_Store to data/test/.DS_Store...
# Downloading data/test/AAPL.csv to data/test/AAPL.csv...
# Downloading data/test/ABBV.csv to data/test/ABBV.csv...
# Downloading data/test/ABT.csv to data/test/ABT.csv...
# Downloading data/test/ACN.csv to data/test/ACN.csv...
# Downloading data/test/ADBE.csv to data/test/ADBE.csv...
# Downloading data/test/ADI.csv to data/test/ADI.csv...
# Downloading data/test/ADP.csv to data/test/ADP.csv...
# Downloading data/test/ADSK.csv to data/test/ADSK.csv...
# Downloading data/test/AEP.csv to data/test/AEP.csv...
# Downloading data/test/AFL.csv to data/test/AFL.csv...
# Downloading data/test/AIG.csv to data/test/AIG.csv...
# Downloading data/test/AJG.csv to data/test/AJG.csv...
# Downloading data/test/ALL.csv to data/test/ALL.csv...
# Downloading data/test/AMAT.csv to data/test/AMAT.csv...
# Downloading data/test/AMGN.csv to data/test/AMGN.csv...
# Downloading data/test/AMP.csv to data/test/AMP.csv...
# Downloading data/test/AMT.csv to data/test/AMT.csv...
# Downloading data/test/AMZN.csv to data/test/AMZN.csv...
# Downloading data/test/AON.csv to data/test/AON.csv...
# Downloading data/test/APD.csv to data/test/APD.csv...
# Downloading data/test/APH.csv to data/test/APH.csv...
# Downloading data/test/AXP.csv to data/test/AXP.csv...
# Downloading data/test/AZO.csv to data/test/AZO.csv...
# Downloading data/test/BA.csv to data/test/BA.csv...
# Downloading data/test/BAC.csv to data/test/BAC.csv...
# Downloading data/test/BDX.csv to data/test/BDX.csv...
# Downloading data/test/BK.csv to data/test/BK.csv...
# Downloading data/test/BKNG.csv to data/test/BKNG.csv...
# Downloading data/test/BLK.csv to data/test/BLK.csv...
# Downloading data/test/BMY.csv to data/test/BMY.csv...
# Downloading data/test/BRK B.csv to data/test/BRK B.csv...
# Downloading data/test/BSX.csv to data/test/BSX.csv...
# Downloading data/test/BX.csv to data/test/BX.csv...
# Downloading data/test/C.csv to data/test/C.csv...
# Downloading data/test/CAT.csv to data/test/CAT.csv...
# Downloading data/test/CB.csv to data/test/CB.csv...
# Downloading data/test/CDNS.csv to data/test/CDNS.csv...
# Downloading data/test/CI.csv to data/test/CI.csv...
# Downloading data/test/CL.csv to data/test/CL.csv...
# Downloading data/test/CMCSA.csv to data/test/CMCSA.csv...
# Downloading data/test/CME.csv to data/test/CME.csv...
# Downloading data/test/CMG.csv to data/test/CMG.csv...
# Downloading data/test/CMI.csv to data/test/CMI.csv...
# Downloading data/test/COF.csv to data/test/COF.csv...
# Downloading data/test/COP.csv to data/test/COP.csv...
# Downloading data/test/COST.csv to data/test/COST.csv...
# Downloading data/test/CPRT.csv to data/test/CPRT.csv...
# Downloading data/test/CRM.csv to data/test/CRM.csv...
# Downloading data/test/CSCO.csv to data/test/CSCO.csv...
# Downloading data/test/CTAS.csv to data/test/CTAS.csv...
# Downloading data/test/CVS.csv to data/test/CVS.csv...
# Downloading data/test/CVX.csv to data/test/CVX.csv...
# Downloading data/test/D.csv to data/test/D.csv...
# Downloading data/test/DE.csv to data/test/DE.csv...
# Downloading data/test/DFS.csv to data/test/DFS.csv...
# Downloading data/test/DHR.csv to data/test/DHR.csv...
# Downloading data/test/DIS.csv to data/test/DIS.csv...
# Downloading data/test/DLR.csv to data/test/DLR.csv...
# Downloading data/test/DUK.csv to data/test/DUK.csv...
# Downloading data/test/ECL.csv to data/test/ECL.csv...
# Downloading data/test/ELV.csv to data/test/ELV.csv...
# Downloading data/test/EMR.csv to data/test/EMR.csv...
# Downloading data/test/EOG.csv to data/test/EOG.csv...
# Downloading data/test/EQIX.csv to data/test/EQIX.csv...
# Downloading data/test/ETN.csv to data/test/ETN.csv...
# Downloading data/test/FCX.csv to data/test/FCX.csv...
# Downloading data/test/FDX.csv to data/test/FDX.csv...
# Downloading data/test/FI.csv to data/test/FI.csv...
# Downloading data/test/FTNT.csv to data/test/FTNT.csv...
# Downloading data/test/GD.csv to data/test/GD.csv...
# Downloading data/test/GE.csv to data/test/GE.csv...
# Downloading data/test/GILD.csv to data/test/GILD.csv...
# Downloading data/test/GM.csv to data/test/GM.csv...
# Downloading data/test/GOOGL.csv to data/test/GOOGL.csv...
# Downloading data/test/GS.csv to data/test/GS.csv...
# Downloading data/test/HCA.csv to data/test/HCA.csv...
# Downloading data/test/HD.csv to data/test/HD.csv...
# Downloading data/test/HON.csv to data/test/HON.csv...
# Downloading data/test/HWM.csv to data/test/HWM.csv...
# Downloading data/test/IBM.csv to data/test/IBM.csv...
# Downloading data/test/ICE.csv to data/test/ICE.csv...
# Downloading data/test/INTC.csv to data/test/INTC.csv...
# Downloading data/test/INTU.csv to data/test/INTU.csv...
# Downloading data/test/ISRG.csv to data/test/ISRG.csv...
# Downloading data/test/ITW.csv to data/test/ITW.csv...
# Downloading data/test/JCI.csv to data/test/JCI.csv...
# Downloading data/test/JNJ.csv to data/test/JNJ.csv...
# Downloading data/test/JPM.csv to data/test/JPM.csv...
# Downloading data/test/KKR.csv to data/test/KKR.csv...
# Downloading data/test/KLAC.csv to data/test/KLAC.csv...
# Downloading data/test/KMB.csv to data/test/KMB.csv...
# Downloading data/test/KMI.csv to data/test/KMI.csv...
# Downloading data/test/KO.csv to data/test/KO.csv...
# Downloading data/test/LLY.csv to data/test/LLY.csv...
# Downloading data/test/LMT.csv to data/test/LMT.csv...
# Downloading data/test/LOW.csv to data/test/LOW.csv...
# Downloading data/test/LRCX.csv to data/test/LRCX.csv...
# Downloading data/test/MA.csv to data/test/MA.csv...
# Downloading data/test/MCD.csv to data/test/MCD.csv...
# Downloading data/test/MCK.csv to data/test/MCK.csv...
# Downloading data/test/MCO.csv to data/test/MCO.csv...
# Downloading data/test/MDLZ.csv to data/test/MDLZ.csv...
# Downloading data/test/MDT.csv to data/test/MDT.csv...
# Downloading data/test/MET.csv to data/test/MET.csv...
# Downloading data/test/META.csv to data/test/META.csv...
# Downloading data/test/MMC.csv to data/test/MMC.csv...
# Downloading data/test/MMM.csv to data/test/MMM.csv...
# Downloading data/test/MO.csv to data/test/MO.csv...
# Downloading data/test/MPC.csv to data/test/MPC.csv...
# Downloading data/test/MRK.csv to data/test/MRK.csv...
# Downloading data/test/MS.csv to data/test/MS.csv...
# Downloading data/test/MSFT.csv to data/test/MSFT.csv...
# Downloading data/test/MSI.csv to data/test/MSI.csv...
# Downloading data/test/MU.csv to data/test/MU.csv...
# Downloading data/test/NEE.csv to data/test/NEE.csv...
# Downloading data/test/NEM.csv to data/test/NEM.csv...
# Downloading data/test/NFLX.csv to data/test/NFLX.csv...
# Downloading data/test/NKE.csv to data/test/NKE.csv...
# Downloading data/test/NOC.csv to data/test/NOC.csv...
# Downloading data/test/NOW.csv to data/test/NOW.csv...
# Downloading data/test/NSC.csv to data/test/NSC.csv...
# Downloading data/test/NVDA.csv to data/test/NVDA.csv...
# Downloading data/test/NXPI.csv to data/test/NXPI.csv...
# Downloading data/test/O.csv to data/test/O.csv...
# Downloading data/test/OKE.csv to data/test/OKE.csv...
# Downloading data/test/ORCL.csv to data/test/ORCL.csv...
# Downloading data/test/ORLY.csv to data/test/ORLY.csv...
# Downloading data/test/PANW.csv to data/test/PANW.csv...
# Downloading data/test/PAYX.csv to data/test/PAYX.csv...
# Downloading data/test/PCAR.csv to data/test/PCAR.csv...
# Downloading data/test/PFE.csv to data/test/PFE.csv...
# Downloading data/test/PG.csv to data/test/PG.csv...
# Downloading data/test/PGR.csv to data/test/PGR.csv...
# Downloading data/test/PH.csv to data/test/PH.csv...
# Downloading data/test/PLD.csv to data/test/PLD.csv...
# Downloading data/test/PM.csv to data/test/PM.csv...
# Downloading data/test/PNC.csv to data/test/PNC.csv...
# Downloading data/test/PSA.csv to data/test/PSA.csv...
# Downloading data/test/PSX.csv to data/test/PSX.csv...
# Downloading data/test/QCOM.csv to data/test/QCOM.csv...
# Downloading data/test/RCL.csv to data/test/RCL.csv...
# Downloading data/test/REGN.csv to data/test/REGN.csv...
# Downloading data/test/ROP.csv to data/test/ROP.csv...
# Downloading data/test/RSG.csv to data/test/RSG.csv...
# Downloading data/test/RTX.csv to data/test/RTX.csv...
# Downloading data/test/SBUX.csv to data/test/SBUX.csv...
# Downloading data/test/SCHW.csv to data/test/SCHW.csv...
# Downloading data/test/SHW.csv to data/test/SHW.csv...
# Downloading data/test/SLB.csv to data/test/SLB.csv...
# Downloading data/test/SNPS.csv to data/test/SNPS.csv...
# Downloading data/test/SO.csv to data/test/SO.csv...
# Downloading data/test/SPG.csv to data/test/SPG.csv...
# Downloading data/test/SPGI.csv to data/test/SPGI.csv...
# Downloading data/test/SRE.csv to data/test/SRE.csv...
# Downloading data/test/SYK.csv to data/test/SYK.csv...
# Downloading data/test/T.csv to data/test/T.csv...
# Downloading data/test/TDG.csv to data/test/TDG.csv...
# Downloading data/test/TFC.csv to data/test/TFC.csv...
# Downloading data/test/TGT.csv to data/test/TGT.csv...
# Downloading data/test/TJX.csv to data/test/TJX.csv...
# Downloading data/test/TMO.csv to data/test/TMO.csv...
# Downloading data/test/TRV.csv to data/test/TRV.csv...
# Downloading data/test/TSLA.csv to data/test/TSLA.csv...
# Downloading data/test/TT.csv to data/test/TT.csv...
# Downloading data/test/TXN.csv to data/test/TXN.csv...
# Downloading data/test/UNH.csv to data/test/UNH.csv...
# Downloading data/test/UNP.csv to data/test/UNP.csv...
# Downloading data/test/UPS.csv to data/test/UPS.csv...
# Downloading data/test/USB.csv to data/test/USB.csv...
# Downloading data/test/V.csv to data/test/V.csv...
# Downloading data/test/VRTX.csv to data/test/VRTX.csv...
# Downloading data/test/VZ.csv to data/test/VZ.csv...
# Downloading data/test/WELL.csv to data/test/WELL.csv...
# Downloading data/test/WFC.csv to data/test/WFC.csv...
# Downloading data/test/WM.csv to data/test/WM.csv...
# Downloading data/test/WMB.csv to data/test/WMB.csv...
# Downloading data/test/WMT.csv to data/test/WMT.csv...
# Downloading data/test/XOM.csv to data/test/XOM.csv...
# Downloading data/test/ZTS.csv to data/test/ZTS.csv...
# Downloading data/train/.DS_Store to data/train/.DS_Store...
# Downloading data/train/AAPL.csv to data/train/AAPL.csv...
# Downloading data/train/ABBV.csv to data/train/ABBV.csv...
# Downloading data/train/ABT.csv to data/train/ABT.csv...
# Downloading data/train/ACN.csv to data/train/ACN.csv...
# Downloading data/train/ADBE.csv to data/train/ADBE.csv...
# Downloading data/train/ADI.csv to data/train/ADI.csv...
# Downloading data/train/ADP.csv to data/train/ADP.csv...
# Downloading data/train/ADSK.csv to data/train/ADSK.csv...
# Downloading data/train/AEP.csv to data/train/AEP.csv...
# Downloading data/train/AFL.csv to data/train/AFL.csv...
# Downloading data/train/AIG.csv to data/train/AIG.csv...
# Downloading data/train/AJG.csv to data/train/AJG.csv...
# Downloading data/train/ALL.csv to data/train/ALL.csv...
# Downloading data/train/AMAT.csv to data/train/AMAT.csv...
# Downloading data/train/AMGN.csv to data/train/AMGN.csv...
# Downloading data/train/AMP.csv to data/train/AMP.csv...
# Downloading data/train/AMT.csv to data/train/AMT.csv...
# Downloading data/train/AMZN.csv to data/train/AMZN.csv...
# Downloading data/train/AON.csv to data/train/AON.csv...
# Downloading data/train/APD.csv to data/train/APD.csv...
# Downloading data/train/APH.csv to data/train/APH.csv...
# Downloading data/train/AXP.csv to data/train/AXP.csv...
# Downloading data/train/AZO.csv to data/train/AZO.csv...
# Downloading data/train/BA.csv to data/train/BA.csv...
# Downloading data/train/BAC.csv to data/train/BAC.csv...
# Downloading data/train/BDX.csv to data/train/BDX.csv...
# Downloading data/train/BK.csv to data/train/BK.csv...
# Downloading data/train/BKNG.csv to data/train/BKNG.csv...
# Downloading data/train/BLK.csv to data/train/BLK.csv...
# Downloading data/train/BMY.csv to data/train/BMY.csv...
# Downloading data/train/BRK B.csv to data/train/BRK B.csv...
# Downloading data/train/BSX.csv to data/train/BSX.csv...
# Downloading data/train/BX.csv to data/train/BX.csv...
# Downloading data/train/C.csv to data/train/C.csv...
# Downloading data/train/CAT.csv to data/train/CAT.csv...
# Downloading data/train/CB.csv to data/train/CB.csv...
# Downloading data/train/CDNS.csv to data/train/CDNS.csv...
# Downloading data/train/CI.csv to data/train/CI.csv...
# Downloading data/train/CL.csv to data/train/CL.csv...
# Downloading data/train/CMCSA.csv to data/train/CMCSA.csv...
# Downloading data/train/CME.csv to data/train/CME.csv...
# Downloading data/train/CMG.csv to data/train/CMG.csv...
# Downloading data/train/CMI.csv to data/train/CMI.csv...
# Downloading data/train/COF.csv to data/train/COF.csv...
# Downloading data/train/COP.csv to data/train/COP.csv...
# Downloading data/train/COST.csv to data/train/COST.csv...
# Downloading data/train/CPRT.csv to data/train/CPRT.csv...
# Downloading data/train/CRM.csv to data/train/CRM.csv...
# Downloading data/train/CSCO.csv to data/train/CSCO.csv...
# Downloading data/train/CTAS.csv to data/train/CTAS.csv...
# Downloading data/train/CVS.csv to data/train/CVS.csv...
# Downloading data/train/CVX.csv to data/train/CVX.csv...
# Downloading data/train/D.csv to data/train/D.csv...
# Downloading data/train/DE.csv to data/train/DE.csv...
# Downloading data/train/DFS.csv to data/train/DFS.csv...
# Downloading data/train/DHR.csv to data/train/DHR.csv...
# Downloading data/train/DIS.csv to data/train/DIS.csv...
# Downloading data/train/DLR.csv to data/train/DLR.csv...
# Downloading data/train/DUK.csv to data/train/DUK.csv...
# Downloading data/train/ECL.csv to data/train/ECL.csv...
# Downloading data/train/ELV.csv to data/train/ELV.csv...
# Downloading data/train/EMR.csv to data/train/EMR.csv...
# Downloading data/train/EOG.csv to data/train/EOG.csv...
# Downloading data/train/EQIX.csv to data/train/EQIX.csv...
# Downloading data/train/ETN.csv to data/train/ETN.csv...
# Downloading data/train/FCX.csv to data/train/FCX.csv...
# Downloading data/train/FDX.csv to data/train/FDX.csv...
# Downloading data/train/FI.csv to data/train/FI.csv...
# Downloading data/train/FTNT.csv to data/train/FTNT.csv...
# Downloading data/train/GD.csv to data/train/GD.csv...
# Downloading data/train/GE.csv to data/train/GE.csv...
# Downloading data/train/GILD.csv to data/train/GILD.csv...
# Downloading data/train/GM.csv to data/train/GM.csv...
# Downloading data/train/GOOGL.csv to data/train/GOOGL.csv...
# Downloading data/train/GS.csv to data/train/GS.csv...
# Downloading data/train/HCA.csv to data/train/HCA.csv...
# Downloading data/train/HD.csv to data/train/HD.csv...
# Downloading data/train/HON.csv to data/train/HON.csv...
# Downloading data/train/HWM.csv to data/train/HWM.csv...
# Downloading data/train/IBM.csv to data/train/IBM.csv...
# Downloading data/train/ICE.csv to data/train/ICE.csv...
# Downloading data/train/INTC.csv to data/train/INTC.csv...
# Downloading data/train/INTU.csv to data/train/INTU.csv...
# Downloading data/train/ISRG.csv to data/train/ISRG.csv...
# Downloading data/train/ITW.csv to data/train/ITW.csv...
# Downloading data/train/JCI.csv to data/train/JCI.csv...
# Downloading data/train/JNJ.csv to data/train/JNJ.csv...
# Downloading data/train/JPM.csv to data/train/JPM.csv...
# Downloading data/train/KKR.csv to data/train/KKR.csv...
# Downloading data/train/KLAC.csv to data/train/KLAC.csv...
# Downloading data/train/KMB.csv to data/train/KMB.csv...
# Downloading data/train/KMI.csv to data/train/KMI.csv...
# Downloading data/train/KO.csv to data/train/KO.csv...
# Downloading data/train/LLY.csv to data/train/LLY.csv...
# Downloading data/train/LMT.csv to data/train/LMT.csv...
# Downloading data/train/LOW.csv to data/train/LOW.csv...
# Downloading data/train/LRCX.csv to data/train/LRCX.csv...
# Downloading data/train/MA.csv to data/train/MA.csv...
# Downloading data/train/MCD.csv to data/train/MCD.csv...
# Downloading data/train/MCK.csv to data/train/MCK.csv...
# Downloading data/train/MCO.csv to data/train/MCO.csv...
# Downloading data/train/MDLZ.csv to data/train/MDLZ.csv...
# Downloading data/train/MDT.csv to data/train/MDT.csv...
# Downloading data/train/MET.csv to data/train/MET.csv...
# Downloading data/train/META.csv to data/train/META.csv...
# Downloading data/train/MMC.csv to data/train/MMC.csv...
# Downloading data/train/MMM.csv to data/train/MMM.csv...
# Downloading data/train/MO.csv to data/train/MO.csv...
# Downloading data/train/MPC.csv to data/train/MPC.csv...
# Downloading data/train/MRK.csv to data/train/MRK.csv...
# Downloading data/train/MS.csv to data/train/MS.csv...
# Downloading data/train/MSFT.csv to data/train/MSFT.csv...
# Downloading data/train/MSI.csv to data/train/MSI.csv...
# Downloading data/train/MU.csv to data/train/MU.csv...
# Downloading data/train/NEE.csv to data/train/NEE.csv...
# Downloading data/train/NEM.csv to data/train/NEM.csv...
# Downloading data/train/NFLX.csv to data/train/NFLX.csv...
# Downloading data/train/NKE.csv to data/train/NKE.csv...
# Downloading data/train/NOC.csv to data/train/NOC.csv...
# Downloading data/train/NOW.csv to data/train/NOW.csv...
# Downloading data/train/NSC.csv to data/train/NSC.csv...
# Downloading data/train/NVDA.csv to data/train/NVDA.csv...
# Downloading data/train/NXPI.csv to data/train/NXPI.csv...
# Downloading data/train/O.csv to data/train/O.csv...
# Downloading data/train/OKE.csv to data/train/OKE.csv...
# Downloading data/train/ORCL.csv to data/train/ORCL.csv...
# Downloading data/train/ORLY.csv to data/train/ORLY.csv...
# Downloading data/train/PANW.csv to data/train/PANW.csv...
# Downloading data/train/PAYX.csv to data/train/PAYX.csv...
# Downloading data/train/PCAR.csv to data/train/PCAR.csv...
# Downloading data/train/PFE.csv to data/train/PFE.csv...
# Downloading data/train/PG.csv to data/train/PG.csv...
# Downloading data/train/PGR.csv to data/train/PGR.csv...
# Downloading data/train/PH.csv to data/train/PH.csv...
# Downloading data/train/PLD.csv to data/train/PLD.csv...
# Downloading data/train/PM.csv to data/train/PM.csv...
# Downloading data/train/PNC.csv to data/train/PNC.csv...
# Downloading data/train/PSA.csv to data/train/PSA.csv...
# Downloading data/train/PSX.csv to data/train/PSX.csv...
# Downloading data/train/QCOM.csv to data/train/QCOM.csv...
# Downloading data/train/RCL.csv to data/train/RCL.csv...
# Downloading data/train/REGN.csv to data/train/REGN.csv...
# Downloading data/train/ROP.csv to data/train/ROP.csv...
# Downloading data/train/RSG.csv to data/train/RSG.csv...
# Downloading data/train/RTX.csv to data/train/RTX.csv...
# Downloading data/train/SBUX.csv to data/train/SBUX.csv...
# Downloading data/train/SCHW.csv to data/train/SCHW.csv...
# Downloading data/train/SHW.csv to data/train/SHW.csv...
# Downloading data/train/SLB.csv to data/train/SLB.csv...
# Downloading data/train/SNPS.csv to data/train/SNPS.csv...
# Downloading data/train/SO.csv to data/train/SO.csv...
# Downloading data/train/SPG.csv to data/train/SPG.csv...
# Downloading data/train/SPGI.csv to data/train/SPGI.csv...
# Downloading data/train/SRE.csv to data/train/SRE.csv...
# Downloading data/train/SYK.csv to data/train/SYK.csv...
# Downloading data/train/T.csv to data/train/T.csv...
# Downloading data/train/TDG.csv to data/train/TDG.csv...
# Downloading data/train/TFC.csv to data/train/TFC.csv...
# Downloading data/train/TGT.csv to data/train/TGT.csv...
# Downloading data/train/TJX.csv to data/train/TJX.csv...
# Downloading data/train/TMO.csv to data/train/TMO.csv...
# Downloading data/train/TRV.csv to data/train/TRV.csv...
# Downloading data/train/TSLA.csv to data/train/TSLA.csv...
# Downloading data/train/TT.csv to data/train/TT.csv...
# Downloading data/train/TXN.csv to data/train/TXN.csv...
# Downloading data/train/UNH.csv to data/train/UNH.csv...
# Downloading data/train/UNP.csv to data/train/UNP.csv...
# Downloading data/train/UPS.csv to data/train/UPS.csv...
# Downloading data/train/USB.csv to data/train/USB.csv...
# Downloading data/train/V.csv to data/train/V.csv...
# Downloading data/train/VRTX.csv to data/train/VRTX.csv...
# Downloading data/train/VZ.csv to data/train/VZ.csv...
# Downloading data/train/WELL.csv to data/train/WELL.csv...
# Downloading data/train/WFC.csv to data/train/WFC.csv...
# Downloading data/train/WM.csv to data/train/WM.csv...
# Downloading data/train/WMB.csv to data/train/WMB.csv...
# Downloading data/train/WMT.csv to data/train/WMT.csv...
# Downloading data/train/XOM.csv to data/train/XOM.csv...
# Downloading data/train/ZTS.csv to data/train/ZTS.csv...

# %%
### LR Finder

# %%
import os
import torch
import pandas as pd

from torch.utils.data import DataLoader
from pytorch_forecasting.data import TimeSeriesDataSet
from pytorch_forecasting.models import TemporalFusionTransformer, Baseline
from pytorch_forecasting.metrics import MAE, MultiLoss, QuantileLoss
from pytorch_forecasting.data.encoders import MultiNormalizer, TorchNormalizer

import pytorch_lightning as pl
from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning.callbacks import EarlyStopping, ModelCheckpoint
from pytorch_lightning.loggers import CSVLogger
from lightning.pytorch.tuner import Tuner

# -----------------------------
# 1. Accelerator/Device Setup
# -----------------------------
if torch.cuda.is_available():
    accelerator = "cuda"
else:
    accelerator = "cpu"
DEVICE = accelerator  # Use this for Trainer and .to()

torch.set_float32_matmul_precision("medium")

# -----------------------------
# 2. Data Loading Function
# -----------------------------
def load_data(folder):
    all_files = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith('.csv')]
    dfs = []
    for file in all_files:
        # df = pd.read_csv(file, index_col=0)  # When There is no Date index
        df = pd.read_csv(file)
        df=df.reset_index(drop=True)
        df=df.drop('date',axis=1) # Drops 'date' column
        df["time_idx"] = range(len(df))
        df["group"] = os.path.basename(file).split('.')[0]
        df["group"] = df["group"].astype(str)
        df.rename(columns={"Close": "target_1", "vclose": "target_2"}, inplace=True)
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# -----------------------------
# 3. Load Datasets
# -----------------------------
train_data_folder = "data/train"
test_data_folder  = "data/test"
oos_data_folder   = "data/oos"

train_df = load_data(train_data_folder)
test_df  = load_data(test_data_folder)
oos_df   = load_data(oos_data_folder)

# -----------------------------
# 4. Multi-Target Dataset
# -----------------------------
training = TimeSeriesDataSet(
    train_df,
    time_idx="time_idx",
    target=["target_1", "target_2"],
    group_ids=["group"],
    max_encoder_length=90,
    max_prediction_length=5,
    static_categoricals=["group"],
    time_varying_known_reals=["time_idx"],
    time_varying_unknown_reals=[
        c for c in train_df.columns if c not in ["group", "time_idx"]#, "target_1", "target_2"]
    ],
    target_normalizer=MultiNormalizer([
        TorchNormalizer(method="identity"),
        TorchNormalizer(method="identity")
    ])
)

validation = TimeSeriesDataSet.from_dataset(training, test_df)
oos = TimeSeriesDataSet.from_dataset(training, oos_df)

# -----------------------------
# 5. DataLoaders
# -----------------------------
train_dataloader = training.to_dataloader(
    train=True, batch_size=64, shuffle=True, num_workers=16, pin_memory=False
)
val_dataloader = validation.to_dataloader(
    train=False, batch_size=64, shuffle=False, num_workers=16, pin_memory=False
)
oos_dataloader = oos.to_dataloader(
    train=False, batch_size=64, shuffle=False, num_workers=16, pin_memory=False
)

import torch.nn as nn

tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate=3e-05,
    lstm_layers=2,
    hidden_size=256,
    attention_head_size=4,
    dropout=0.35,
    hidden_continuous_size=256,
    output_size=[1, 1],  # single output per target for MSE
    loss=MultiLoss([
        nn.MSELoss(),
        nn.MSELoss()
    ]),
    log_interval=200,
    reduce_on_plateau_patience=5,
).to(DEVICE)


print(f"Number of parameters in network: {tft.size() / 1e3:.1f}k")

# -----------------------------
# 7. LightningModule Wrapper
# -----------------------------
class TFTLightningModule(LightningModule):
    def __init__(self, tft_model):
        super().__init__()
        self.tft_model = tft_model
        # Save the learning rate in hparams for LR finder purposes
        self.save_hyperparameters({'learning_rate': tft_model.hparams.learning_rate})
        
    def forward(self, x):
        return self.tft_model(x)
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        out = self(x)
        pred = out["prediction"]
        loss = self.tft_model.loss(pred, y)
        self.log("train_loss", loss, prog_bar=True, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        out = self(x)
        pred = out["prediction"]
        loss = self.tft_model.loss(pred, y)
        self.log("val_loss", loss, prog_bar=True, on_epoch=True)
        return loss

    def configure_optimizers(self):
        return self.tft_model.configure_optimizers()

tft_module = TFTLightningModule(tft).to(DEVICE)

# -----------------------------
# 8. Learning Rate Finder
# -----------------------------
pl.seed_everything(42)
# IMPORTANT: Create an LR finder trainer with an empty callbacks list.
lr_finder_trainer = Trainer(
    max_epochs=1,
    accelerator=accelerator,
    devices=1,
    precision=32,
    callbacks=[],  # ensure no LR finder callback is pre-configured
)

tuner = Tuner(lr_finder_trainer)
try:
    lr_find_result = tuner.lr_find(
        tft_module,
        train_dataloaders=train_dataloader,
        val_dataloaders=val_dataloader,
        max_lr=1e-4,
        min_lr=5e-7,
        num_training=200,  # specify training steps to run
    )
except _TunerExitException:
    print("LR Finder exited early (expected behavior).")
    lr_find_result = tuner.lr_find(
        tft_module,
        train_dataloaders=train_dataloader,
        val_dataloaders=val_dataloader,
        max_lr=1e-4,
        min_lr=5e-7,
        num_training=200,
        update_attr=False,  # Prevent automatic LR assignment
    )

suggested_lr = lr_find_result.suggestion()
print(f"Suggested learning rate: {suggested_lr:.2e}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/ubuntu/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Number of parameters in network: 32358.6k
# `Trainer.fit` stopped: `max_steps=200` reached.00 [00:35<00:00,  5.79it/s]
# Finding best initial lr: 100%|██████████| 200/200 [00:35<00:00,  5.60it/s]
# Learning rate set to 4.171863120490385e-05
# Restoring states from the checkpoint path at /home/ubuntu/tft_v0/.lr_find_c7a1755c-2b83-49a5-b6e6-f36cd007a8e8.ckpt
# Restored all states from the checkpoint at /home/ubuntu/tft_v0/.lr_find_c7a1755c-2b83-49a5-b6e6-f36cd007a8e8.ckpt
# LR finder finished with an exception (expected):
# ---------------------------------------------------------------------------
# _TunerExitException                       Traceback (most recent call last)
# /tmp/ipykernel_2426/2867914049.py in <module>
#     164 try:
# --> 165     lr_find_result = tuner.lr_find(
#     166         tft_module,
#
# ~/.local/lib/python3.10/site-packages/lightning/pytorch/tuner/tuning.py in lr_find(self, model, train_dataloaders, val_dataloaders, dataloaders, datamodule, method, min_lr, max_lr, num_training, mode, early_stop_threshold, update_attr, attr_name)
#     179
# --> 180         self._trainer.fit(model, train_dataloaders, val_dataloaders, datamodule)
#     181
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     538         self.training = True
# --> 539         call._call_and_handle_interrupt(
#     540             self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47         return trainer_fn(*args, **kwargs)
#      48
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     574         )
# --> 575         self._run(model, ckpt_path=ckpt_path)
#     576
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py in _run(self, model, ckpt_path)
#     961         if self.state.fn == TrainerFn.FITTING:
# --> 962             call._call_callback_hooks(self, "on_fit_start")
#     963             call._call_lightning_module_hook(self, "on_fit_start")
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py in _call_callback_hooks(trainer, hook_name, monitoring_callbacks, *args, **kwargs)
#     221             with trainer.profiler.profile(f"[Callback]{callback.state_key}.{hook_name}"):
# --> 222                 fn(trainer, trainer.lightning_module, *args, **kwargs)
#     223
#
# ~/.local/lib/python3.10/site-packages/lightning/pytorch/callbacks/lr_finder.py in on_fit_start(self, trainer, pl_module)
#     129     def on_fit_start(self, trainer: "pl.Trainer", pl_module: "pl.LightningModule") -> None:
# --> 130         self.lr_find(trainer, pl_module)
#
# ~/.local/lib/python3.10/site-packages/lightning/pytorch/callbacks/lr_finder.py in lr_find(self, trainer, pl_module)
#     125         if self._early_exit:
# --> 126             raise _TunerExitException()
#     127
#
# _TunerExitException:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2426/2867914049.py in <module>
#     174     print("LR finder finished with an exception (expected):", e)
#     175     # Try to get a result without update_attr if necessary:
# --> 176     lr_find_result = tuner.lr_find(
#     177         tft_module,
#     178         train_dataloaders=train_dataloader,
#
# ~/.local/lib/python3.10/site-packages/lightning/pytorch/tuner/tuning.py in lr_find(self, model, train_dataloaders, val_dataloaders, dataloaders, datamodule, method, min_lr, max_lr, num_training, mode, early_stop_threshold, update_attr, attr_name)
#     160
#     161         _check_tuner_configuration(train_dataloaders, val_dataloaders, dataloaders, method)
# --> 162         _check_lr_find_configuration(self._trainer)
#     163
#     164         # local import to avoid circular import
#
# ~/.local/lib/python3.10/site-packages/lightning/pytorch/tuner/tuning.py in _check_lr_find_configuration(trainer)
#     215     configured_callbacks = [cb for cb in trainer.callbacks if isinstance(cb, LearningRateFinder)]
#     216     if configured_callbacks:
# --> 217         raise ValueError(
#     218             "Trainer is already configured with a `LearningRateFinder` callback."
#     219             "Please remove it if you want to use the Tuner."
#
# ValueError: Trainer is already configured with a `LearningRateFinder` callback.Please remove it if you want to use the Tuner.

# %%
import os
import torch
import pandas as pd
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader
from pytorch_forecasting.data import TimeSeriesDataSet
from pytorch_forecasting.models import TemporalFusionTransformer
from pytorch_forecasting.metrics import MultiLoss, QuantileLoss, MAE
from pytorch_forecasting.data.encoders import MultiNormalizer, TorchNormalizer

import pytorch_lightning as pl
from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning.callbacks import EarlyStopping, ModelCheckpoint
from pytorch_lightning.loggers import CSVLogger

# -----------------------------
# 1. Device Setup
# -----------------------------
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_float32_matmul_precision("medium")  # For NVIDIA Tensor Cores
print("Using device:", DEVICE)

# -----------------------------
# 2. Data Loading
# -----------------------------
def load_data(folder):
    all_files = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith('.csv')]
    dfs = []
    for file in all_files:
        # df = pd.read_csv(file, index_col=0)  # When There is no Date index
        df = pd.read_csv(file)
        df=df.reset_index(drop=True)
        df=df.drop('date',axis=1) # Drops 'date' column
        df["time_idx"] = range(len(df))
        df["group"] = os.path.basename(file).split('.')[0]
        df["group"] = df["group"].astype(str)
        # rename 'Close' -> target_1, 'vclose' -> target_2
        df.rename(columns={"Close":"target_1","vclose":"target_2"}, inplace=True)
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

train_data_folder = "data/train"
test_data_folder  = "data/test"
oos_data_folder   = "data/oos"

train_df = load_data(train_data_folder)
test_df  = load_data(test_data_folder)
oos_df   = load_data(oos_data_folder)

# -----------------------------
# 3. Multi-Target Dataset
# -----------------------------
training = TimeSeriesDataSet(
    train_df,
    time_idx="time_idx",
    target=["target_1", "target_2"],
    group_ids=["group"],
    max_encoder_length=90,
    max_prediction_length=5,
    static_categoricals=["group"],
    time_varying_known_reals=["time_idx"],
    time_varying_unknown_reals=[
        c for c in train_df.columns if c not in ["group","time_idx"]#,"target_1","target_2"]
    ],
    target_normalizer=MultiNormalizer([
        TorchNormalizer(method="identity"),  # target_1
        TorchNormalizer(method="identity")   # target_2
    ])
)

# validation & OOS sets with predict_mode=False -> keep target data
validation = TimeSeriesDataSet.from_dataset(training, test_df, predict_mode=False)
oos        = TimeSeriesDataSet.from_dataset(training, oos_df,  predict_mode=False)

# -----------------------------
# 4. DataLoaders
# -----------------------------
train_dataloader = training.to_dataloader(
    train=True, batch_size=64, shuffle=True, num_workers=16, pin_memory=False
)
val_dataloader = validation.to_dataloader(
    train=False, batch_size=64, shuffle=False, num_workers=16, pin_memory=False
)
oos_dataloader = oos.to_dataloader(
    train=False, batch_size=16, shuffle=False, num_workers=16, pin_memory=False
)

# -----------------------------
# 5. Define Multi-Target TFT Model w/ Quantile Loss
# -----------------------------
import torch.nn as nn

tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate=4.171863120490385e-05,
    lstm_layers=2,
    hidden_size=256,
    attention_head_size=4,
    dropout=0.35,
    hidden_continuous_size=256,
    output_size=[1, 1],  # single output per target for MSE
    loss=MultiLoss([
        nn.MSELoss(),
        nn.MSELoss()
    ]),
    log_interval=200,
    reduce_on_plateau_patience=5,
).to(DEVICE)

print(f"Number of params in network: {tft.size() / 1e3:.1f}k")

# -----------------------------
# 6. LightningModule
# -----------------------------
class TFTLightningModule(LightningModule):
    def __init__(self, tft_model):
        super().__init__()
        self.tft_model = tft_model

    def forward(self, x):
        return self.tft_model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        # 'y' is a tuple: ([target0_tensor, target1_tensor], None)
        out = self(x)
        pred = out["prediction"]  # list: 0 => target0, 1 => target1
        loss = self.tft_model.loss(pred, y)  # automatically handles multi-target
        self.log("train_loss", loss, prog_bar=True, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        out = self(x)
        pred = out["prediction"]
        loss = self.tft_model.loss(pred, y)
        self.log("val_loss", loss, prog_bar=True, on_epoch=True)
        return loss

    def configure_optimizers(self):
        return self.tft_model.configure_optimizers()

    def predict_step(self, batch, batch_idx, dataloader_idx=0):
        # If the batch is a (x, y) tuple, we only pass x to the model
        if isinstance(batch, (tuple, list)):
            x = batch[0]
        else:
            x = batch
        return self(x)

tft_module = TFTLightningModule(tft).to(DEVICE)

# Optional: training setup
early_stop_callback = EarlyStopping(monitor="val_loss", patience=7, mode="min")
checkpoint_callback = ModelCheckpoint(
    dirpath="checkpoints/",
    filename="my-tft-{epoch:02d}-{val_loss:.2f}",
    save_top_k=1,
    monitor="val_loss",
    mode="min"
)

trainer = Trainer(
    max_epochs=35,   # set higher for real training
    accelerator="gpu" if DEVICE == "cuda" else "cpu",
    devices=1,
    precision=32,
    logger=CSVLogger("logs", name="tft_multi_target_quantile"),
    callbacks=[early_stop_callback, checkpoint_callback],
)

# -----------------------------
# 7. (Un)comment to Train or Load
# -----------------------------
trainer.fit(tft_module, train_dataloader, val_dataloader)
# best_ckpt_path = "checkpoints/my-tft-epoch=XX-val_loss=YY.ckpt"
# tft_module = TFTLightningModule.load_from_checkpoint(best_ckpt_path, tft_model=tft).to(DEVICE)
# tft_module.eval()

# -----------------------------
# 8. Helper: Recursively move batch to device
# -----------------------------
def move_to_device(batch_x, device):
    """Ensure all Tensors in batch_x are on the same device."""
    if isinstance(batch_x, torch.Tensor):
        return batch_x.to(device)
    elif isinstance(batch_x, dict):
        return {k: move_to_device(v, device) for k, v in batch_x.items()}
    elif isinstance(batch_x, list):
        return [move_to_device(item, device) for item in batch_x]
    else:
        return batch_x
# Out:
# Using device: cuda
# /home/ubuntu/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /home/ubuntu/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | tft_model | TemporalFusionTransformer | 32.4 M | train
# ----------------------------------------------------------------
# 32.4 M    Trainable params
# 0         Non-trainable params
# 32.4 M    Total params
# 129.435   Total estimated model params size (MB)
# 1206      Modules in train mode
# 0         Modules in eval mode
# Number of params in network: 32358.6k
# Epoch 0: 100%|██████████| 4620/4620 [13:10<00:00,  5.84it/s, v_num=0, train_loss_step=0.656]
# idation: |          | 0/? [00:00<?, ?it/s]
# idation:   0%|          | 0/1147 [00:00<?, ?it/s]
# idation DataLoader 0:   0%|          | 0/1147 [00:00<?, ?it/s]
# idation DataLoader 0:   0%|          | 1/1147 [00:00<01:19, 14.38it/s]
# idation DataLoader 0:   0%|          | 2/1147 [00:00<01:23, 13.68it/s]
# idation DataLoader 0:   0%|          | 3/1147 [00:00<01:20, 14.13it/s]
# idation DataLoader 0:   0%|          | 4/1147 [00:00<01:19, 14.37it/s]
# idation DataLoader 0:   0%|          | 5/1147 [00:00<01:21, 14.09it/s]
# idation DataLoader 0:   1%|          | 6/1147 [00:00<01:20, 14.26it/s]
# idation DataLoader 0:   1%|          | 7/1147 [00:00<01:19, 14.38it/s]
# idation DataLoader 0:   1%|          | 8/1147 [00:00<01:20, 14.14it/s]
# idation DataLoader 0:   1%|          | 9/1147 [00:00<01:20, 14.17it/s]
# idation DataLoader 0:   1%|          | 10/1147 [00:00<01:19, 14.25it/s]
# idation DataLoader 0:   1%|          | 11/1147 [00:00<01:20, 14.18it/s]
# idation DataLoader 0:   1%|          | 12/1147 [00:00<01:20, 14.15it/s]
# idation DataLoader 0:   1%|          | 13/1147 [00:00<01:19, 14.21it/s]
# idation DataLoader 0:   1%|          | 14/1147 [00:00<01:19, 14.28it/s]
# idation DataLoader 0:   1%|▏         | 15/1147 [00:01<01:18, 14.35it/s]
# idation DataLoader 0:   1%|▏         | 16/1147 [00:01<01:18, 14.35it/s]
# idation DataLoader 0:   1%|▏         | 17/1147 [00:01<01:21, 13.86it/s]
# idation DataLoader 0:   2%|▏         | 18/1147 [00:01<01:21, 13.93it/s]
# idation DataLoader 0:   2%|▏         | 19/1147 [00:01<01:20, 14.00it/s]
# idation DataLoader 0:   2%|▏         | 20/1147 [00:01<01:20, 14.06it/s]
# idation DataLoader 0:   2%|▏         | 21/1147 [00:01<01:19, 14.10it/s]
# idation DataLoader 0:   2%|▏         | 22/1147 [00:01<01:19, 14.09it/s]
# idation DataLoader 0:   2%|▏         | 23/1147 [00:01<01:19, 14.13it/s]
# idation DataLoader 0:   2%|▏         | 24/1147 [00:01<01:19, 14.17it/s]
# idation DataLoader 0:   2%|▏         | 25/1147 [00:01<01:18, 14.20it/s]
# idation DataLoader 0:   2%|▏         | 26/1147 [00:01<01:18, 14.24it/s]
# idation DataLoader 0:   2%|▏         | 27/1147 [00:01<01:18, 14.31it/s]
# idation DataLoader 0:   2%|▏         | 28/1147 [00:01<01:17, 14.35it/s]
# idation DataLoader 0:   3%|▎         | 29/1147 [00:02<01:17, 14.38it/s]
# idation DataLoader 0:   3%|▎         | 30/1147 [00:02<01:17, 14.41it/s]
# idation DataLoader 0:   3%|▎         | 31/1147 [00:02<01:17, 14.44it/s]
# idation DataLoader 0:   3%|▎         | 32/1147 [00:02<01:17, 14.43it/s]
# idation DataLoader 0:   3%|▎         | 33/1147 [00:02<01:17, 14.43it/s]
# idation DataLoader 0:   3%|▎         | 34/1147 [00:02<01:17, 14.43it/s]
# idation DataLoader 0:   3%|▎         | 35/1147 [00:02<01:17, 14.43it/s]
# idation DataLoader 0:   3%|▎         | 36/1147 [00:02<01:17, 14.42it/s]
# idation DataLoader 0:   3%|▎         | 37/1147 [00:02<01:16, 14.42it/s]
# idation DataLoader 0:   3%|▎         | 38/1147 [00:02<01:16, 14.42it/s]
# idation DataLoader 0:   3%|▎         | 39/1147 [00:02<01:16, 14.42it/s]
# idation DataLoader 0:   3%|▎         | 40/1147 [00:02<01:16, 14.42it/s]
# idation DataLoader 0:   4%|▎         | 41/1147 [00:02<01:16, 14.42it/s]
# idation DataLoader 0:   4%|▎         | 42/1147 [00:02<01:16, 14.43it/s]
# idation DataLoader 0:   4%|▎         | 43/1147 [00:02<01:16, 14.44it/s]
# idation DataLoader 0:   4%|▍         | 44/1147 [00:03<01:16, 14.44it/s]
# idation DataLoader 0:   4%|▍         | 45/1147 [00:03<01:16, 14.44it/s]
# idation DataLoader 0:   4%|▍         | 46/1147 [00:03<01:16, 14.44it/s]
# idation DataLoader 0:   4%|▍         | 47/1147 [00:03<01:16, 14.44it/s]
# idation DataLoader 0:   4%|▍         | 48/1147 [00:03<01:16, 14.44it/s]
# idation DataLoader 0:   4%|▍         | 49/1147 [00:03<01:16, 14.44it/s]
# idation DataLoader 0:   4%|▍         | 50/1147 [00:03<01:15, 14.44it/s]
# idation DataLoader 0:   4%|▍         | 51/1147 [00:03<01:16, 14.41it/s]
# idation DataLoader 0:   5%|▍         | 52/1147 [00:03<01:15, 14.41it/s]
# idation DataLoader 0:   5%|▍         | 53/1147 [00:03<01:15, 14.41it/s]
# idation DataLoader 0:   5%|▍         | 54/1147 [00:03<01:15, 14.41it/s]
# idation DataLoader 0:   5%|▍         | 55/1147 [00:03<01:15, 14.41it/s]
# idation DataLoader 0:   5%|▍         | 56/1147 [00:03<01:15, 14.43it/s]
# idation DataLoader 0:   5%|▍         | 57/1147 [00:03<01:15, 14.43it/s]
# idation DataLoader 0:   5%|▌         | 58/1147 [00:04<01:15, 14.44it/s]
# idation DataLoader 0:   5%|▌         | 59/1147 [00:04<01:15, 14.44it/s]
# idation DataLoader 0:   5%|▌         | 60/1147 [00:04<01:15, 14.44it/s]
# idation DataLoader 0:   5%|▌         | 61/1147 [00:04<01:15, 14.44it/s]
# idation DataLoader 0:   5%|▌         | 62/1147 [00:04<01:15, 14.44it/s]
# idation DataLoader 0:   5%|▌         | 63/1147 [00:04<01:15, 14.44it/s]
# idation DataLoader 0:   6%|▌         | 64/1147 [00:04<01:14, 14.44it/s]
# idation DataLoader 0:   6%|▌         | 65/1147 [00:04<01:14, 14.44it/s]
# idation DataLoader 0:   6%|▌         | 66/1147 [00:04<01:14, 14.44it/s]
# idation DataLoader 0:   6%|▌         | 67/1147 [00:04<01:14, 14.44it/s]
# idation DataLoader 0:   6%|▌         | 68/1147 [00:04<01:14, 14.44it/s]
# idation DataLoader 0:   6%|▌         | 69/1147 [00:04<01:14, 14.43it/s]
# idation DataLoader 0:   6%|▌         | 70/1147 [00:04<01:14, 14.43it/s]
# idation DataLoader 0:   6%|▌         | 71/1147 [00:04<01:14, 14.44it/s]
# idation DataLoader 0:   6%|▋         | 72/1147 [00:04<01:14, 14.45it/s]
# idation DataLoader 0:   6%|▋         | 73/1147 [00:05<01:14, 14.45it/s]
# idation DataLoader 0:   6%|▋         | 74/1147 [00:05<01:14, 14.45it/s]
# idation DataLoader 0:   7%|▋         | 75/1147 [00:05<01:14, 14.45it/s]
# idation DataLoader 0:   7%|▋         | 76/1147 [00:05<01:14, 14.44it/s]
# idation DataLoader 0:   7%|▋         | 77/1147 [00:05<01:14, 14.44it/s]
# idation DataLoader 0:   7%|▋         | 78/1147 [00:05<01:14, 14.44it/s]
# idation DataLoader 0:   7%|▋         | 79/1147 [00:05<01:13, 14.44it/s]
# idation DataLoader 0:   7%|▋         | 80/1147 [00:05<01:13, 14.43it/s]
# idation DataLoader 0:   7%|▋         | 81/1147 [00:05<01:13, 14.43it/s]
# idation DataLoader 0:   7%|▋         | 82/1147 [00:05<01:13, 14.43it/s]
# idation DataLoader 0:   7%|▋         | 83/1147 [00:05<01:13, 14.43it/s]
# idation DataLoader 0:   7%|▋         | 84/1147 [00:05<01:13, 14.43it/s]
# idation DataLoader 0:   7%|▋         | 85/1147 [00:05<01:13, 14.44it/s]
# idation DataLoader 0:   7%|▋         | 86/1147 [00:05<01:13, 14.44it/s]
# idation DataLoader 0:   8%|▊         | 87/1147 [00:06<01:13, 14.44it/s]
# idation DataLoader 0:   8%|▊         | 88/1147 [00:06<01:13, 14.44it/s]
# idation DataLoader 0:   8%|▊         | 89/1147 [00:06<01:13, 14.45it/s]
# idation DataLoader 0:   8%|▊         | 90/1147 [00:06<01:13, 14.45it/s]
# idation DataLoader 0:   8%|▊         | 91/1147 [00:06<01:13, 14.45it/s]
# idation DataLoader 0:   8%|▊         | 92/1147 [00:06<01:13, 14.44it/s]
# idation DataLoader 0:   8%|▊         | 93/1147 [00:06<01:12, 14.44it/s]
# idation DataLoader 0:   8%|▊         | 94/1147 [00:06<01:12, 14.44it/s]
# idation DataLoader 0:   8%|▊         | 95/1147 [00:06<01:12, 14.44it/s]
# idation DataLoader 0:   8%|▊         | 96/1147 [00:06<01:12, 14.44it/s]
# idation DataLoader 0:   8%|▊         | 97/1147 [00:06<01:12, 14.44it/s]
# idation DataLoader 0:   9%|▊         | 98/1147 [00:06<01:12, 14.44it/s]
# idation DataLoader 0:   9%|▊         | 99/1147 [00:06<01:12, 14.44it/s]
# idation DataLoader 0:   9%|▊         | 100/1147 [00:06<01:12, 14.44it/s]
# idation DataLoader 0:   9%|▉         | 101/1147 [00:06<01:12, 14.45it/s]
# idation DataLoader 0:   9%|▉         | 102/1147 [00:07<01:12, 14.45it/s]
# idation DataLoader 0:   9%|▉         | 103/1147 [00:07<01:12, 14.45it/s]
# idation DataLoader 0:   9%|▉         | 104/1147 [00:07<01:12, 14.45it/s]
# idation DataLoader 0:   9%|▉         | 105/1147 [00:07<01:12, 14.45it/s]
# idation DataLoader 0:   9%|▉         | 106/1147 [00:07<01:12, 14.45it/s]
# idation DataLoader 0:   9%|▉         | 107/1147 [00:07<01:11, 14.45it/s]
# idation DataLoader 0:   9%|▉         | 108/1147 [00:07<01:11, 14.45it/s]
# idation DataLoader 0:  10%|▉         | 109/1147 [00:07<01:11, 14.44it/s]
# idation DataLoader 0:  10%|▉         | 110/1147 [00:07<01:11, 14.44it/s]
# idation DataLoader 0:  10%|▉         | 111/1147 [00:07<01:11, 14.43it/s]
# idation DataLoader 0:  10%|▉         | 112/1147 [00:07<01:11, 14.43it/s]
# idation DataLoader 0:  10%|▉         | 113/1147 [00:07<01:11, 14.43it/s]
# idation DataLoader 0:  10%|▉         | 114/1147 [00:07<01:11, 14.44it/s]
# idation DataLoader 0:  10%|█         | 115/1147 [00:07<01:11, 14.44it/s]
# idation DataLoader 0:  10%|█         | 116/1147 [00:08<01:11, 14.44it/s]
# idation DataLoader 0:  10%|█         | 117/1147 [00:08<01:11, 14.44it/s]
# idation DataLoader 0:  10%|█         | 118/1147 [00:08<01:11, 14.45it/s]
# idation DataLoader 0:  10%|█         | 119/1147 [00:08<01:11, 14.44it/s]
# idation DataLoader 0:  10%|█         | 120/1147 [00:08<01:11, 14.44it/s]
# idation DataLoader 0:  11%|█         | 121/1147 [00:08<01:11, 14.45it/s]
# idation DataLoader 0:  11%|█         | 122/1147 [00:08<01:10, 14.44it/s]
# idation DataLoader 0:  11%|█         | 123/1147 [00:08<01:10, 14.44it/s]
# idation DataLoader 0:  11%|█         | 124/1147 [00:08<01:10, 14.44it/s]
# idation DataLoader 0:  11%|█         | 125/1147 [00:08<01:10, 14.44it/s]
# idation DataLoader 0:  11%|█         | 126/1147 [00:08<01:10, 14.44it/s]
# idation DataLoader 0:  11%|█         | 127/1147 [00:08<01:10, 14.44it/s]
# idation DataLoader 0:  11%|█         | 128/1147 [00:08<01:10, 14.44it/s]
# idation DataLoader 0:  11%|█         | 129/1147 [00:08<01:10, 14.44it/s]
# idation DataLoader 0:  11%|█▏        | 130/1147 [00:08<01:10, 14.45it/s]
# idation DataLoader 0:  18%|█▊        | 201/1147 [00:13<01:05, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 202/1147 [00:13<01:05, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 203/1147 [00:14<01:05, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 204/1147 [00:14<01:05, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 205/1147 [00:14<01:05, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 206/1147 [00:14<01:05, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 207/1147 [00:14<01:04, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 208/1147 [00:14<01:04, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 209/1147 [00:14<01:04, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 210/1147 [00:14<01:04, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 211/1147 [00:14<01:04, 14.46it/s]
# idation DataLoader 0:  18%|█▊        | 212/1147 [00:14<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▊        | 213/1147 [00:14<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▊        | 214/1147 [00:14<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▊        | 215/1147 [00:14<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▉        | 216/1147 [00:14<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▉        | 217/1147 [00:14<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▉        | 218/1147 [00:15<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▉        | 219/1147 [00:15<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▉        | 220/1147 [00:15<01:04, 14.47it/s]
# idation DataLoader 0:  19%|█▉        | 221/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  19%|█▉        | 222/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  19%|█▉        | 223/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  20%|█▉        | 224/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  20%|█▉        | 225/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  20%|█▉        | 226/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  20%|█▉        | 227/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  20%|█▉        | 228/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  20%|█▉        | 229/1147 [00:15<01:03, 14.47it/s]
# idation DataLoader 0:  20%|██        | 230/1147 [00:15<01:03, 14.48it/s]
# idation DataLoader 0:  20%|██        | 231/1147 [00:15<01:03, 14.48it/s]
# idation DataLoader 0:  20%|██        | 232/1147 [00:16<01:03, 14.48it/s]
# idation DataLoader 0:  20%|██        | 233/1147 [00:16<01:03, 14.48it/s]
# idation DataLoader 0:  20%|██        | 234/1147 [00:16<01:03, 14.48it/s]
# idation DataLoader 0:  20%|██        | 235/1147 [00:16<01:02, 14.48it/s]
# idation DataLoader 0:  51%|█████▏    | 588/1147 [00:40<00:38, 14.47it/s]
# idation DataLoader 0:  51%|█████▏    | 589/1147 [00:40<00:38, 14.47it/s]
# idation DataLoader 0:  51%|█████▏    | 590/1147 [00:40<00:38, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 591/1147 [00:40<00:38, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 592/1147 [00:40<00:38, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 593/1147 [00:40<00:38, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 594/1147 [00:41<00:38, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 595/1147 [00:41<00:38, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 596/1147 [00:41<00:38, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 597/1147 [00:41<00:38, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 598/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 599/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 600/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 601/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  52%|█████▏    | 602/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 603/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 604/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 605/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 606/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 607/1147 [00:41<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 608/1147 [00:42<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 609/1147 [00:42<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 610/1147 [00:42<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 611/1147 [00:42<00:37, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 612/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  53%|█████▎    | 613/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▎    | 614/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▎    | 615/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▎    | 616/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 617/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 618/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 619/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 620/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 621/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 622/1147 [00:42<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 623/1147 [00:43<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 624/1147 [00:43<00:36, 14.47it/s]
# idation DataLoader 0:  54%|█████▍    | 625/1147 [00:43<00:36, 14.47it/s]
# idation DataLoader 0:  55%|█████▍    | 626/1147 [00:43<00:36, 14.47it/s]
# idation DataLoader 0:  55%|█████▍    | 627/1147 [00:43<00:35, 14.47it/s]
# idation DataLoader 0:  55%|█████▍    | 628/1147 [00:43<00:35, 14.47it/s]
# idation DataLoader 0:  55%|█████▍    | 629/1147 [00:43<00:35, 14.47it/s]
# idation DataLoader 0:  55%|█████▍    | 630/1147 [00:43<00:35, 14.46it/s]
# idation DataLoader 0:  55%|█████▌    | 631/1147 [00:43<00:35, 14.46it/s]
# idation DataLoader 0:  55%|█████▌    | 632/1147 [00:43<00:35, 14.46it/s]
# idation DataLoader 0:  55%|█████▌    | 633/1147 [00:43<00:35, 14.46it/s]
# idation DataLoader 0:  55%|█████▌    | 634/1147 [00:43<00:35, 14.46it/s]
# idation DataLoader 0:  55%|█████▌    | 635/1147 [00:43<00:35, 14.47it/s]
# idation DataLoader 0:  55%|█████▌    | 636/1147 [00:43<00:35, 14.47it/s]
# idation DataLoader 0:  56%|█████▌    | 637/1147 [00:44<00:35, 14.47it/s]
# idation DataLoader 0:  56%|█████▌    | 638/1147 [00:44<00:35, 14.47it/s]
# ...
# idation DataLoader 0:  81%|████████▏ | 933/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  81%|████████▏ | 934/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 935/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 936/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 937/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 938/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 939/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 940/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 941/1147 [01:04<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 942/1147 [01:05<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 943/1147 [01:05<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 944/1147 [01:05<00:14, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 945/1147 [01:05<00:13, 14.49it/s]
# idation DataLoader 0:  82%|████████▏ | 946/1147 [01:05<00:13, 14.49it/s]
# idation DataLoader 0:  83%|████████▎ | 947/1147 [01:05<00:13, 14.49it/s]
# idation DataLoader 0:  83%|████████▎ | 948/1147 [01:05<00:13, 14.49it/s]
# idation DataLoader 0:  83%|████████▎ | 949/1147 [01:05<00:13, 14.49it/s]
# idation DataLoader 0:  83%|████████▎ | 950/1147 [01:05<00:13, 14.49it/s]
# idation DataLoader 0:  95%|█████████▍| 1086/1147 [01:15<00:04, 14.48it/s]
# idation DataLoader 0:  95%|█████████▍| 1087/1147 [01:15<00:04, 14.48it/s]
# idation DataLoader 0:  95%|█████████▍| 1088/1147 [01:15<00:04, 14.48it/s]
# idation DataLoader 0:  95%|█████████▍| 1089/1147 [01:15<00:04, 14.48it/s]
# idation DataLoader 0:  95%|█████████▌| 1090/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  95%|█████████▌| 1091/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  95%|█████████▌| 1092/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  95%|█████████▌| 1093/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  95%|█████████▌| 1094/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  95%|█████████▌| 1095/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▌| 1096/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▌| 1097/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▌| 1098/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▌| 1099/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▌| 1100/1147 [01:15<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▌| 1101/1147 [01:16<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▌| 1102/1147 [01:16<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▌| 1103/1147 [01:16<00:03, 14.48it/s]
# idation DataLoader 0:  96%|█████████▋| 1104/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  96%|█████████▋| 1105/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  96%|█████████▋| 1106/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1107/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1108/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1109/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1110/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1111/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1112/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1113/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1114/1147 [01:16<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1115/1147 [01:17<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1116/1147 [01:17<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1117/1147 [01:17<00:02, 14.48it/s]
# idation DataLoader 0:  97%|█████████▋| 1118/1147 [01:17<00:02, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1119/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1120/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1121/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1122/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1123/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1124/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1125/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1126/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1127/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1128/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  98%|█████████▊| 1129/1147 [01:17<00:01, 14.48it/s]
# idation DataLoader 0:  99%|█████████▊| 1130/1147 [01:18<00:01, 14.48it/s]
# idation DataLoader 0:  99%|█████████▊| 1131/1147 [01:18<00:01, 14.48it/s]
# idation DataLoader 0:  99%|█████████▊| 1132/1147 [01:18<00:01, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1133/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1134/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1135/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1136/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1137/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1138/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1139/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1140/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0:  99%|█████████▉| 1141/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0: 100%|█████████▉| 1142/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0: 100%|█████████▉| 1143/1147 [01:18<00:00, 14.48it/s]
# idation DataLoader 0: 100%|█████████▉| 1144/1147 [01:19<00:00, 14.48it/s]
# idation DataLoader 0: 100%|█████████▉| 1145/1147 [01:19<00:00, 14.48it/s]
# idation DataLoader 0: 100%|█████████▉| 1146/1147 [01:19<00:00, 14.48it/s]
# idation DataLoader 0: 100%|██████████| 1147/1147 [01:19<00:00, 14.48it/s]
# Epoch 2:  55%|█████▍    | 2525/4620 [07:12<05:58,  5.84it/s, v_num=0, train_loss_step=0.222, val_loss=0.506, train_loss_epoch=0.448]

# %%
torch.save(tft_module.state_dict(), "mar3_model.pth")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import os
import numpy as np
from pytorch_forecasting.metrics import MAE

def move_to_device(batch_x, device):
    """Ensure all Tensors in batch_x are on the same device."""
    if isinstance(batch_x, torch.Tensor):
        return batch_x.to(device)
    elif isinstance(batch_x, dict):
        return {k: move_to_device(v, device) for k, v in batch_x.items()}
    elif isinstance(batch_x, list):
        return [move_to_device(item, device) for item in batch_x]
    else:
        return batch_x

# Define the stock symbol (you can replace this or loop through a list of symbols)
stock_symbols = 'snex'  # Add more symbols here if needed
stock_symbols = [stock_symbols.upper()]
# Load TixSigMu.csv data
mu_sig_df = pd.read_csv('./data/TixMuSig.csv')

import torch

# Set device
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)

# Later when creating your model:
tft_module = TFTLightningModule(tft).to(DEVICE)

# And when processing data:
x = move_to_device(x, DEVICE)


# Function to process a single stock symbol
def plot_predictions_for_symbol(stock_symbol):
    # Load the dataframes
    # train_data_folder = "data/train"
    # test_data_folder  = "data/test"
    oos_data_folder   = "data/oos"

    # train_df = load_data(train_data_folder)
    # test_df  = load_data(test_data_folder)
    oos_df   = load_data(oos_data_folder)

    # Filter the data for the specific stock
    stock_oos_df = oos_df[oos_df["group"] == stock_symbol]

    # Extracting raw data from 'target_1' (price) and 'target_2' (volatility) from the historical data (scaled)
    historical_price = stock_oos_df['target_1'].values
    mu_p = mu_sig_df.loc[mu_sig_df['ticker'] == stock_symbol, 'closemu'].values[0]
    sig_p = mu_sig_df.loc[mu_sig_df['ticker'] == stock_symbol, 'closesig'].values[0]
    historical_volatility = stock_oos_df['target_2'].values
    mu_v = mu_sig_df.loc[mu_sig_df['ticker'] == stock_symbol, 'volmu'].values[0]
    sig_v = mu_sig_df.loc[mu_sig_df['ticker'] == stock_symbol, 'volsig'].values[0]


    # Descale the historical data for price and volatility
    historical_price_descaled = historical_price * sig_p + mu_p
    historical_volatility_descaled = historical_volatility * sig_v + mu_v

    # Select only the last 65 periods for plotting
    historical_price_last_65 = historical_price_descaled[-65:]
    historical_volatility_last_65 = historical_volatility_descaled[-65:]

    # Make predictions for price and volatility (using predict_mode=True)
    eq_dataset = TimeSeriesDataSet.from_dataset(training, stock_oos_df, predict_mode=True)
    eq_dataloader = eq_dataset.to_dataloader(
        train=False,
        batch_size=len(eq_dataset),  # All samples in one batch
        shuffle=False,
        num_workers=0,  # Use 0 workers to avoid multiprocessing issues
        pin_memory=False
    )

    # Predict on the stock OOS data
    with torch.no_grad():
        for batch in eq_dataloader:
            x, y_tuple = batch
            y_list, _ = y_tuple
            actual_target0 = y_list[0]  # Target_0 actual values (price)

            # If x is a dictionary, inspect it
            if isinstance(x, dict):
                encoder_cont = x.get('encoder_cont', None)  # Get the continuous features if available
                # print(f"Shape of encoder_cont: {encoder_cont.shape}")  # Print the shape of 'encoder_cont'
            
            # Move input data to device (GPU or CPU)
            x = move_to_device(x, DEVICE)

            # Make predictions
            out = tft_module(x)
            preds = out["prediction"]
            
            median_pred_target0 = preds[0][:, :, 0].cpu()
            median_pred_target1 = preds[1][:, :, 0].cpu()

    
    # Extract predictions from the batch
    price_preds = median_pred_target0
    vol_preds = median_pred_target1

    price_preds_descaled = price_preds*sig_p + mu_p
    vol_preds_descaled = vol_preds*sig_v + mu_v

    # Flatten the predictions to ensure the correct shape for plotting
    price_preds_flat = price_preds_descaled.flatten()  # Flatten the price predictions
    vol_preds_flat = vol_preds_descaled.flatten()  # Flatten the volatility predictions

    # Get the range for plotting (next 5 periods after historical data)
    forecast_start_idx = len(historical_price_last_65)  # First index after the last 65 periods
    forecast_end_idx = forecast_start_idx + 5  # 5 prediction periods

    # Plot the actual price, actual volatility, and predicted values (descaled)
    fig, ax = plt.subplots(2, 1, figsize=(10, 12))

    # Plot actual price and predicted price
    ax[0].plot(range(len(historical_price_last_65)), historical_price_last_65, label=f'{stock_symbol} Actual Price (target_1)', color='black')
    ax[0].plot(range(forecast_start_idx, forecast_end_idx), price_preds_flat, 'r--', label=f'{stock_symbol} Predicted Price')
    ax[0].set_title(f"{stock_symbol} - Price Predictions vs. Actuals")
    ax[0].set_xlabel("Time Steps")
    ax[0].set_ylabel("Price")
    ax[0].legend()
    ax[0].grid()

    # Plot actual volatility and predicted volatility
    ax[1].plot(range(len(historical_volatility_last_65)), historical_volatility_last_65, label=f'{stock_symbol} Actual Volatility (target_2)', color='black')
    ax[1].plot(range(forecast_start_idx, forecast_end_idx), vol_preds_flat, 'r--', label=f'{stock_symbol} Predicted Volatility')
    ax[1].set_title(f"{stock_symbol} - Volatility Predictions vs. Actuals")
    ax[1].set_xlabel("Time Steps")
    ax[1].set_ylabel("Volatility")
    ax[1].legend()
    ax[1].grid()

    # Adjust layout to prevent overlap
    plt.tight_layout()

    # Show the plot
    plt.show()

# Loop over all stock symbols
for stock_symbol in stock_symbols:
    plot_predictions_for_symbol(stock_symbol)


# aapl_oos_df = oos_df[oos_df["group"] == stock_symbol]
stock_oos_df = oos_df[oos_df["group"] == stock_symbol]
print(f"Number of OOS records for {stock_symbol}: {len(stock_oos_df)}")

# Create a dataset for that specific stock using the training dataset parameters.
eq_dataset = TimeSeriesDataSet.from_dataset(training, stock_oos_df, predict_mode=False)

# To obtain a single batch containing all data for, set batch_size to the size of the dataset.
eq_dataloader_backtest = eq_dataset.to_dataloader(
    train=False,
    batch_size=len(eq_dataset),  # all samples in one batch
    shuffle=False,
    num_workers=0,  # use 0 workers to avoid multiprocessing issues
    pin_memory=False
)

# Predict on the OOS data.
eq_preds = []
eq_actuals = []

with torch.no_grad():
    for batch in eq_dataloader_backtest:
        x, y_tuple = batch
        y_list, _ = y_tuple
        actual_target0 = y_list[1]  # target_1 actual values
        x = move_to_device(x, DEVICE)
        out = tft_module(x)
        preds = out["prediction"]
        median_pred_target0 = preds[1][:, :, 0].cpu()  # median quantile for target_1
        eq_preds.append(median_pred_target0)
        eq_actuals.append(actual_target0)

# Since we have only one batch, take the first element.
eq_pred_tensor = eq_preds[-1]
eq_actual_tensor = eq_actuals[-1]

# -----------------------------
# Compute a Metric (e.g., MAE) on the Specific Stock Data
# -----------------------------
mae_metric = MAE()
eq_mae = mae_metric(eq_pred_tensor, eq_actual_tensor)
print(f"MAE for {stock_symbol} (target_0, median): {eq_mae.item():.4f}")
# Out:
# Using device: cuda
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3411/171587328.py in <module>
#      33
#      34 # And when processing data:
# ---> 35 x = move_to_device(x, DEVICE)
#      36
#      37
#
# NameError: name 'x' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import os
import numpy as np
from pytorch_forecasting.metrics import MAE
device= "gpu"
def move_to_device(batch_x, device):
    """Ensure all Tensors in batch_x are on the same device."""
    if isinstance(batch_x, torch.Tensor):
        return batch_x.to(device)
    elif isinstance(batch_x, dict):
        return {k: move_to_device(v, device) for k, v in batch_x.items()}
    elif isinstance(batch_x, list):
        return [move_to_device(item, device) for item in batch_x]
    else:
        return batch_x

# Define the stock symbol (you can replace this or loop through a list of symbols)
stock_symbols = 'ibm'  # Add more symbols here if needed
stock_symbols = [stock_symbols.upper()]
# Load TixSigMu.csv data
mu_sig_df = pd.read_csv('./data/TixMuSig.csv')

# Function to process a single stock symbol
def plot_predictions_for_symbol(stock_symbol):
    # Load the dataframes
    # train_data_folder = "data/train"
    # test_data_folder  = "data/test"
    oos_data_folder   = "data/oos"

    # train_df = load_data(train_data_folder)
    # test_df  = load_data(test_data_folder)
    oos_df   = load_data(oos_data_folder)

    # Filter the data for the specific stock
    stock_oos_df = oos_df[oos_df["group"] == stock_symbol]

    # Extracting raw data from 'target_1' (price) and 'target_2' (volatility) from the historical data (scaled)
    historical_price = stock_oos_df['target_1'].values
    mu_p = mu_sig_df.loc[mu_sig_df['ticker'] == stock_symbol, 'closemu'].values[0]
    sig_p = mu_sig_df.loc[mu_sig_df['ticker'] == stock_symbol, 'closesig'].values[0]
    historical_volatility = stock_oos_df['target_2'].values
    mu_v = mu_sig_df.loc[mu_sig_df['ticker'] == stock_symbol, 'volmu'].values[0]
    sig_v = mu_sig_df.loc[mu_sig_df['ticker'] == stock_symbol, 'volsig'].values[0]


    # Descale the historical data for price and volatility
    historical_price_descaled = historical_price * sig_p + mu_p
    historical_volatility_descaled = historical_volatility * sig_v + mu_v

    # Select only the last 65 periods for plotting
    historical_price_last_65 = historical_price_descaled[-65:]
    historical_volatility_last_65 = historical_volatility_descaled[-65:]

    # Make predictions for price and volatility (using predict_mode=True)
    eq_dataset = TimeSeriesDataSet.from_dataset(training, stock_oos_df, predict_mode=True)
    eq_dataloader = eq_dataset.to_dataloader(
        train=False,
        batch_size=len(eq_dataset),  # All samples in one batch
        shuffle=False,
        num_workers=0,  # Use 0 workers to avoid multiprocessing issues
        pin_memory=False
    )

    # Predict on the stock OOS data
    with torch.no_grad():
        for batch in eq_dataloader:
            x, y_tuple = batch
            y_list, _ = y_tuple
            actual_target0 = y_list[0]  # Target_0 actual values (price)

            # If x is a dictionary, inspect it
            if isinstance(x, dict):
                encoder_cont = x.get('encoder_cont', None)  # Get the continuous features if available
                # print(f"Shape of encoder_cont: {encoder_cont.shape}")  # Print the shape of 'encoder_cont'
            
            # Move input data to device (GPU or CPU)
            x = move_to_device(x, DEVICE)

            # Make predictions
            out = tft_module(x)
            preds = out["prediction"]
            
            # Extract the price and volatility predictions
            median_pred_target0 = preds[0][:, :, 0].cpu()  # Median quantile for target_0 (price)
            median_pred_target1 = preds[1][:, :, 0].cpu()  # Median quantile for target_1 (volatility)
    
    # Extract predictions from the batch
    price_preds = median_pred_target0
    vol_preds = median_pred_target1

    price_preds_descaled = price_preds*sig_p + mu_p
    vol_preds_descaled = vol_preds*sig_v + mu_v

    # Flatten the predictions to ensure the correct shape for plotting
    price_preds_flat = price_preds_descaled.flatten()  # Flatten the price predictions
    vol_preds_flat = vol_preds_descaled.flatten()  # Flatten the volatility predictions

    # Get the range for plotting (next 5 periods after historical data)
    forecast_start_idx = len(historical_price_last_65)  # First index after the last 65 periods
    forecast_end_idx = forecast_start_idx + 5  # 5 prediction periods

    # Plot the actual price, actual volatility, and predicted values (descaled)
    fig, ax = plt.subplots(2, 1, figsize=(10, 12))

    # Plot actual price and predicted price
    ax[0].plot(range(len(historical_price_last_65)), historical_price_last_65, label=f'{stock_symbol} Actual Price (target_1)', color='black')
    ax[0].plot(range(forecast_start_idx, forecast_end_idx), price_preds_flat, 'r--', label=f'{stock_symbol} Predicted Price')
    ax[0].set_title(f"{stock_symbol} - Price Predictions vs. Actuals")
    ax[0].set_xlabel("Time Steps")
    ax[0].set_ylabel("Price")
    ax[0].legend()
    ax[0].grid()

    # Plot actual volatility and predicted volatility
    ax[1].plot(range(len(historical_volatility_last_65)), historical_volatility_last_65, label=f'{stock_symbol} Actual Volatility (target_2)', color='black')
    ax[1].plot(range(forecast_start_idx, forecast_end_idx), vol_preds_flat, 'r--', label=f'{stock_symbol} Predicted Volatility')
    ax[1].set_title(f"{stock_symbol} - Volatility Predictions vs. Actuals")
    ax[1].set_xlabel("Time Steps")
    ax[1].set_ylabel("Volatility")
    ax[1].legend()
    ax[1].grid()

    # Adjust layout to prevent overlap
    plt.tight_layout()

    # Show the plot
    plt.show()

# Loop over all stock symbols
for stock_symbol in stock_symbols:
    plot_predictions_for_symbol(stock_symbol)


# aapl_oos_df = oos_df[oos_df["group"] == stock_symbol]
stock_oos_df = oos_df[oos_df["group"] == stock_symbol]
print(f"Number of OOS records for {stock_symbol}: {len(stock_oos_df)}")

# Create a dataset for that specific stock using the training dataset parameters.
eq_dataset = TimeSeriesDataSet.from_dataset(training, stock_oos_df, predict_mode=True)

# To obtain a single batch containing all data for, set batch_size to the size of the dataset.
eq_dataloader_backtest = eq_dataset.to_dataloader(
    train=False,
    batch_size=len(eq_dataset),  # all samples in one batch
    shuffle=False,
    num_workers=0,  # use 0 workers to avoid multiprocessing issues
    pin_memory=False
)

# Predict on the OOS data.
eq_preds = []
eq_actuals = []

with torch.no_grad():
    for batch in eq_dataloader_backtest:
        x, y_tuple = batch
        y_list, _ = y_tuple
        actual_target0 = y_list[1]  # target_1 actual values
        x = move_to_device(x, DEVICE)
        out = tft_module(x)
        preds = out["prediction"]
        median_pred_target0 = preds[1][:, :, 0].cpu()  # median quantile for target_1
        eq_preds.append(median_pred_target0)
        eq_actuals.append(actual_target0)

# Since we have only one batch, take the first element.
eq_pred_tensor = eq_preds[-1]
eq_actual_tensor = eq_actuals[-1]

# -----------------------------
# Compute a Metric (e.g., MAE) on the Specific Stock Data
# -----------------------------
mae_metric = MAE()
eq_mae = mae_metric(eq_pred_tensor, eq_actual_tensor)
print(f"MAE for {stock_symbol} (target_0, median): {eq_mae.item():.4f}")
# Out:
# Number of OOS records for IBM: 252
# MAE for IBM (target_0, median): 0.5304
